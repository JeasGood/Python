# %% [markdown]
# <a href="https://colab.research.google.com/github/JeasGood/Python/blob/master/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
im1=cv2.imread("images.png",cv2.IMREAD_GRAYSCALE)
im1=cv2.cvtColor(im1,cv2.COLOR_BGR2RGB)
im2=cv2.imread("j.png",cv2.IMREAD_GRAYSCALE)
im2=cv2.cvtColor(im2,cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.imshow(im1)
plt.subplot(122)
plt.imshow(im2)
plt.show()
